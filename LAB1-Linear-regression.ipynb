# %% [markdown]
# # Machine Learning workshop LAB 1.
#
# Understand basic concept of machine learning with Linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt

num_points = 200
vectors_set = []
for i in xrange(num_points):
  x = np.random.normal(5,5)+15
  #y = (x-100)*0.90 + np.random.random_integers(-4,4)
  y =  x*1000+ (np.random.normal(0,3))*1000
  vectors_set.append([x,y])
  
x_data = [v[0] for v in vectors_set ]
y_data = [v[1] for v in vectors_set ]

plt.plot(x_data,y_data,'ro')
plt.ylim([0,40000])
plt.xlim([5,35])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# /Users/terrycho/anaconda/envs/tensorflow13/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y-y_data))
optimizer = tf.train.GradientDescentOptimizer(0.0015)
train = optimizer.minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in xrange(10):
  _,w_val,b_val,loss_val=sess.run([train,W,b,loss])
  print(w_val,b_val,loss_val)
  
  plt.plot(x_data,y_data,'ro')
  plt.plot(x_data,w_val*x_data + b_val)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.show()
# Out:
# (array([ 1254.31677246], dtype=float32), array([ 60.21022415], dtype=float32), 4.3389747e+08)
# (array([ 958.97009277], dtype=float32), array([ 46.04678345], dtype=float32), 32127936.0)
# (array([ 1028.52062988], dtype=float32), array([ 49.39762115], dtype=float32), 9847501.0)
# (array([ 1012.14135742], dtype=float32), array([ 48.62401199], dtype=float32), 8611924.0)
# (array([ 1015.99786377], dtype=float32), array([ 48.82167435], dtype=float32), 8543406.0)
# (array([ 1015.08886719], dtype=float32), array([ 48.79060364], dtype=float32), 8539604.0)
# (array([ 1015.30218506], dtype=float32), array([ 48.81339645], dtype=float32), 8539394.0)
# (array([ 1015.25128174], dtype=float32), array([ 48.8235054], dtype=float32), 8539383.0)
# (array([ 1015.26245117], dtype=float32), array([ 48.83659363], dtype=float32), 8539382.0)
# (array([ 1015.25915527], dtype=float32), array([ 48.84898376], dtype=float32), 8539382.0)

# %% [markdown]
# # Add feeding code to Linear regression code

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
# declare Placeholder x
x = tf.placeholder(tf.float32, shape=[None])

y = W * x + b

loss = tf.reduce_mean(tf.square(y-y_data))
optimizer = tf.train.GradientDescentOptimizer(0.0015)
train = optimizer.minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in xrange(10):
  # feed x_data to Variable 'x'
  _,w_val,b_val,loss_val =sess.run([train,W,b,loss],feed_dict={x:x_data})
  print(w_val,b_val,loss_val)
  
  plt.plot(x_data,y_data,'ro')
  plt.plot(x_data,w_val*x_data + b_val)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.show()
# Out:
# (array([ 1254.27697754], dtype=float32), array([ 60.2001915], dtype=float32), 4.3375568e+08)
# (array([ 958.97998047], dtype=float32), array([ 46.03913498], dtype=float32), 32119990.0)
# (array([ 1028.51879883], dtype=float32), array([ 49.38941193], dtype=float32), 9847059.0)
# (array([ 1012.14233398], dtype=float32), array([ 48.61594009], dtype=float32), 8611901.0)
# (array([ 1015.99810791], dtype=float32), array([ 48.81356812], dtype=float32), 8543404.0)
# (array([ 1015.08929443], dtype=float32), array([ 48.78250504], dtype=float32), 8539606.0)
# (array([ 1015.30255127], dtype=float32), array([ 48.80529785], dtype=float32), 8539395.0)
# (array([ 1015.25164795], dtype=float32), array([ 48.81541061], dtype=float32), 8539382.0)
# (array([ 1015.26293945], dtype=float32), array([ 48.82850647], dtype=float32), 8539382.0)
# (array([ 1015.25952148], dtype=float32), array([ 48.84089279], dtype=float32), 8539382.0)
